# %%
import os
path="C:/Users/Krovi/OneDrive/Desktop/AI"
files=os.listdir(path)
print(files)
# Out:
# ['.ipynb_checkpoints', 'Basic.ipynb']

# %%
for file in files:
    print(file)
# Out:
# .ipynb_checkpoints
# Basic.ipynb

# %%
path="C:/Users/Krovi/OneDrive/Desktop"
for file in os.listdir(path):
    full_path=os.path.join(path,file)
    if os.path.isfile(full_path):
        print(file)
# Out:
# archive (6).zip
# BSTdel.txt
# Camera.lnk
# CAST.jpeg
# caste.jpeg
# caste_aadhar_marksheet.pdf
# ChatBot.py
# desktop.ini
# Dev-C++.lnk
# dspLab3.jpeg
# DSPsyllabus.jpeg
# Image to PDF 20260129 07.18.20.pdf
# image.jpeg
# IMDB-Movie-Data.xlsx
# Lab Task -PHP.pdf
# Lab01.py
# LL.java
# MongoDBCompass.lnk
# Multi sim.zip
# NI License Activator 1.2 (1).exe
# paasport_size_photo.pdf
# passport.jpeg
# random.py
# sah.txt
# sahithi.js
# signature.pdf
# Stress_Dataset.csv
# typing.txt
# Visual Studio Code.lnk
# Wireless Display.lnk
# WT Unit-3 OAuth2.0.pptx
# WTsyllabus.jpeg

# %%
#to Move files
import shutil
shutil.move("C:/Users/Krovi/OneDrive/Desktop/others/sah.txt","C:/Users/Krovi/OneDrive/Desktop/sah.txt")
print("MOVED successfully")
# Out:
# MOVED successfully

# %%
import os

print(os.listdir(r"C:\Users\Krovi\OneDrive\Desktop"))
# Out:
# ['AI', 'archive (6).zip', 'BSTdel.txt', 'c', 'Camera.lnk', 'CAST.jpeg', 'caste.jpeg', 'caste_aadhar_marksheet.pdf', 'ChatBot.py', 'desktop.ini', 'Dev-C++.lnk', 'devc++', 'DSP', 'dspLab3.jpeg', 'DSPsyllabus.jpeg', 'exercise02', 'GIT', 'gitBash', 'Image to PDF 20260129 07.18.20.pdf', 'image.jpeg', 'IMDB-Movie-Data.xlsx', 'IMP', 'java', 'java projects', 'jsTasks', 'Lab Task -PHP.pdf', 'Lab01.py', 'libraries', 'LL.java', 'MongoDBCompass.lnk', 'Multi sim.zip', 'NI License Activator 1.2 (1).exe', 'Nielit', 'others', 'paasport_size_photo.pdf', 'pack', 'passport.jpeg', 'pdfs', 'python_projects', 'random.py', 'React js', 'sah.txt', 'sahithi.js', 'signature.pdf', 'some', 'Stress_Dataset.csv', 'typing.txt', 'Visual Studio Code.lnk', 'weather', 'Wireless Display.lnk', 'WT', 'WT Unit-3 OAuth2.0.pptx', 'WTsyllabus.jpeg']

# %%
#moving ALL files from one folder to another
import os 
import shutil
path="C:/Users/Krovi/OneDrive/Desktop/IMP"
files=os.listdir(path)
for file in files:
    filename,extension=os.path.splitext(file)
    extension=extension[1:]
    if extension=="jpg" or extension=="jpeg":
        shutil.move(path+"/"+file,path+"/Image/"+file)
    elif extension=="pdf":
        shutil.move(path+"/"+file,path+"/PDF/"+file)
    elif extension=="txt":
        shutil.move(path+"/"+file,path+"/Text/"+file)
