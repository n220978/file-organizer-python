# %%
import pandas as pd
data={
    "StudyHours":[1,2,3,4,5,6,7,8],
    "Passed":[0,0,0,1,1,1,1,1]
}
df = pd.DataFrame(data)

# %%
X=df[["StudyHours"]]
y=df["Passed"]

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
model.fit(X,y)
# Out:
# LogisticRegression()

# %%
prediction=model.predict([[2]])
print(prediction)
# Out:
# [0]
# C:\Users\krovi\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
model.predict_proba([[2]])
# Out:
# C:\Users\krovi\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([[0.84640881, 0.15359119]])

# %%
import matplotlib.pyplot as plt
plt.scatter(X,y)
plt.plot(X,model.predict(X))
plt.xlabel("Study Hours")
plt.ylabel("Pass / Fail")
plt.show()
