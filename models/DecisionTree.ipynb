# %%
import pandas as pd

data = {
    "StudyHours":[2,3,4,6,7],
    "SleepHours":[8,7,6,5,4],
    "Passed":[0,0,1,1,1]
}

df = pd.DataFrame(data)

# %%
X=df[["StudyHours","SleepHours"]]
y=df["Passed"]

# %%
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier()
model.fit(X,y)
# Out:
# DecisionTreeClassifier()

# %%
prediction=model.predict([[5,6]])
print(prediction)
# Out:
# [1]
# C:\Users\krovi\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt
plt.figure(figsize=(8,5))
plot_tree(model,feature_names=["StudyHours","SleepHours"],filled=True)
plt.show()

# %%
#Challenge
import pandas as pd
data1={
    "Age":[25,30,35,40,45],
    "Income":[30000,40000,50000,70000,90000],
    "BuyProduct":[0,0,1,1,1]

}
df1=pd.DataFrame(data1)

# %%
X=df1[["Age","Income"]]
y=df1["BuyProduct"]

# %%
from sklearn.tree import DecisionTreeClassifier
model1=DecisionTreeClassifier()
model1.fit(X,y)
# Out:
# DecisionTreeClassifier()

# %%
prediction1=model1.predict([[33,45000]])
print(prediction1)
# Out:
# [1]
# C:\Users\krovi\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt
plt.figure(figsize=(8,5))
plot_tree(model1,feature_names=["Age","Income"],filled=True)
plt.show()
